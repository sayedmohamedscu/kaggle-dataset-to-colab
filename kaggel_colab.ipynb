# %% [markdown]
# <a href="https://colab.research.google.com/github/sayedmohamedscu/kaggle-dataset-to-colab/blob/master/kaggel_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# create an Api token

# %% [markdown]
# ![Screenshot from 2023-03-26 15-07-32.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot from 2023-03-26 15-07-51.png](data:image/png;base64,...)

# %% [markdown]
# download dataset from Kaggle

# %%
# !mkdir -p ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d ahmedhamada0/brain-tumor-detection
# Out:
# ...
#  90% 76.0M/84.0M [00:00<00:00, 210MB/s]
# 100% 84.0M/84.0M [00:00<00:00, 179MB/s]

# %%
# !kaggle datasets download -d ravirajsinh45/real-life-industrial-dataset-of-casting-product
# Out:
# ...
#  89% 89.0M/100M [00:01<00:00, 100MB/s]
# 100% 100M/100M [00:01<00:00, 88.5MB/s]

# %%
# !unzip "/content/real-life-industrial-dataset-of-casting-product.zip"
